# %%
from matplotlib.pyplot import plot
import numpy as np
import pandas as pd

# %%
dataset_path = '/home/amanda/Dropbox/trabalho/testes/aplicacoes/rolling mills/rolling_mills_drift_alltog03.txt'
data = np.loadtxt(dataset_path)
print(data.shape)
# Out:
# (9486, 3)

# %%
plot(data[:, 2])
