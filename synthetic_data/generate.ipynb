# %%
import numpy as np

f1 = np.zeros(50)
f2 = np.zeros(50)
f3 = np.zeros(50)
S1 = np.zeros(50)

for key, x in enumerate(np.arange(0, 1, 1/50)):
    f1[key] = 1/30 * (x ** 6 - 22.5 * x ** 5 + 189.5 * x ** 4 - 735.75 * x ** 3 + 1296.56 * x ** 2 - 822.66 * x + 180)
    f2[key] = 0.08 * x ** 6 - 1.8 * x ** 5 + 15.16 * x ** 4 - 58.86 * x ** 3 + 103.72 * x ** 2 - 65.81 * x + 8
    f3[key] = -0.1 * x ** 6 - 2.25 * x ** 5 + 18.95 * x ** 4 + 73.5 * x ** 3 - 1296 * x ** 2 + 85 * x - 7.5

# %%
from matplotlib.pyplot import plot
import pandas as pd
import seaborn as sns

df_1 = pd.DataFrame(f1 * f2, columns=['Time series #1'])
#df_2 = pd.DataFrame(f1 * f3, columns=['Time series #2'])
#df_3 = pd.DataFrame(f2 * f3, columns=['Time series #3'])
#df_4 = pd.DataFrame(f3 * f2 * f3, columns=['Time series #4'])
#df = pd.concat([df_1, df_2, df_3])#, df_4])

sns.lineplot(data=df_1)
